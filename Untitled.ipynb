# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout
import matplotlib.pyplot as plt
import yfinance as yf

# %%
# Step 1: Data Collection
# Fetch historical stock data
stock_data = yf.download('NFLX', start='2010-01-01', end='2023-08-01')
# We are interested in 'Close' price
close_prices = stock_data['Close']
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
# Step 2: Data Preprocessing
# Convert the data into a numpy array
data = close_prices.values.reshape(-1, 1)

# Scaling the data between 0 and 1
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(data)

# %%
# Create a dataset with the last 60 days' closing prices and the next day's closing price
def create_dataset(dataset, time_step=60):
    X, y = [], []
    for i in range(len(dataset) - time_step - 1):
        X.append(dataset[i:(i + time_step), 0])
        y.append(dataset[i + time_step, 0])
    return np.array(X), np.array(y)

time_step = 60
X, y = create_dataset(scaled_data, time_step)

# Reshape X to be [samples, time steps, features]
X = X.reshape(X.shape[0], X.shape[1], 1)

# Split data into training and testing sets
training_size = int(len(X) * 0.8)
X_train, X_test = X[:training_size], X[training_size:]
y_train, y_test = y[:training_size], y[training_size:]

# %%
# Step 3: Building the LSTM Model
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1], 1)))
model.add(Dropout(0.2))
model.add(LSTM(units=50, return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(units=25))
model.add(Dense(units=1))

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')
# Out:
# I:\M\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# Step 4: Training the Model
model.fit(X_train, y_train, batch_size=32, epochs=100)
# Out:
# Epoch 1/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 8s 40ms/step - loss: 0.0136
# Epoch 2/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - loss: 9.8282e-04
# Epoch 3/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - loss: 6.8434e-04
# Epoch 4/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - loss: 7.6814e-04
# Epoch 5/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - loss: 7.1468e-04
# Epoch 6/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - loss: 6.3695e-04
# Epoch 7/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: 6.3279e-04
# Epoch 8/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - loss: 5.7566e-04
# Epoch 9/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - loss: 6.2143e-04
# Epoch 10/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - loss: 5.5261e-04
# Epoch 11/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: 5.7046e-04
# Epoch 12/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: 4.8927e-04
# Epoch 13/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - loss: 5.9685e-04
# Epoch 14/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: 6.2152e-04
# Epoch 15/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - loss: 5.1722e-04
# Epoch 16/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: 5.4662e-04
# Epoch 17/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - loss: 5.6759e-04
# Epoch 18/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - loss: 4.9530e-04
# Epoch 19/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - loss: 5.7613e-04
# Epoch 20/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - loss: 5.0702e-04
# Epoch 21/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 5s 42ms/step - loss: 5.5718e-04
# Epoch 22/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - loss: 4.4634e-04
# Epoch 23/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: 5.7265e-04
# Epoch 24/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - loss: 5.2805e-04
# Epoch 25/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - loss: 5.1064e-04
# Epoch 26/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - loss: 6.3961e-04
# Epoch 27/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 5s 42ms/step - loss: 4.5999e-04
# Epoch 28/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - loss: 5.0153e-04
# Epoch 29/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 5s 42ms/step - loss: 4.4785e-04
# Epoch 30/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 5s 42ms/step - loss: 4.5060e-04
# Epoch 31/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - loss: 4.3263e-04
# Epoch 32/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - loss: 4.6721e-04
# Epoch 33/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: 4.9298e-04
# Epoch 34/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - loss: 4.2795e-04
# Epoch 35/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - loss: 4.7764e-04
# Epoch 36/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - loss: 4.7517e-04
# Epoch 37/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - loss: 4.4314e-04
# Epoch 38/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - loss: 4.8281e-04
# Epoch 39/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - loss: 4.6045e-04
# Epoch 40/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - loss: 4.5545e-04
# Epoch 41/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - loss: 4.3622e-04
# Epoch 42/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - loss: 4.6095e-04
# Epoch 43/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - loss: 4.6596e-04
# Epoch 44/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - loss: 4.9266e-04
# Epoch 45/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - loss: 4.6951e-04
# Epoch 46/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - loss: 4.6923e-04
# Epoch 47/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - loss: 4.4792e-04
# Epoch 48/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - loss: 4.3240e-04
# Epoch 49/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - loss: 4.1796e-04
# Epoch 50/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - loss: 4.8695e-04
# Epoch 51/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 5s 42ms/step - loss: 4.2037e-04
# Epoch 52/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - loss: 4.2054e-04
# Epoch 53/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - loss: 4.3635e-04
# Epoch 54/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: 3.9074e-04
# Epoch 55/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: 4.2596e-04
# Epoch 56/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - loss: 4.5910e-04
# Epoch 57/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: 4.0492e-04
# Epoch 58/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - loss: 4.2952e-04
# Epoch 59/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - loss: 4.0299e-04
# Epoch 60/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: 4.7979e-04
# Epoch 61/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - loss: 4.6778e-04
# Epoch 62/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 5s 43ms/step - loss: 3.9899e-04
# Epoch 63/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 5s 42ms/step - loss: 4.1898e-04
# Epoch 64/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - loss: 4.1172e-04
# Epoch 65/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 5s 43ms/step - loss: 4.1242e-04
# Epoch 66/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 4s 44ms/step - loss: 4.4902e-04
# Epoch 67/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 4s 51ms/step - loss: 4.2225e-04
# Epoch 68/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - loss: 4.2855e-04
# Epoch 69/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - loss: 4.5040e-04
# Epoch 70/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - loss: 4.5266e-04
# Epoch 71/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - loss: 4.5397e-04
# Epoch 72/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 5s 47ms/step - loss: 4.2782e-04
# Epoch 73/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - loss: 4.2099e-04
# Epoch 74/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step - loss: 3.6965e-04
# Epoch 75/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - loss: 4.5364e-04
# Epoch 76/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - loss: 4.4296e-04
# Epoch 77/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 4s 44ms/step - loss: 4.5263e-04
# Epoch 78/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - loss: 4.4111e-04
# Epoch 79/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 4s 43ms/step - loss: 4.6930e-04
# Epoch 80/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - loss: 4.0636e-04
# Epoch 81/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - loss: 4.5380e-04
# Epoch 82/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 4s 43ms/step - loss: 5.3825e-04
# Epoch 83/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - loss: 4.0626e-04
# Epoch 84/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - loss: 3.5214e-04
# Epoch 85/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - loss: 4.2259e-04
# Epoch 86/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - loss: 5.3380e-04
# Epoch 87/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - loss: 3.9707e-04
# Epoch 88/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - loss: 4.3659e-04
# Epoch 89/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - loss: 4.2090e-04
# Epoch 90/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - loss: 5.0749e-04
# Epoch 91/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - loss: 4.3163e-04
# Epoch 92/100
# 27/84 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 3.2650e-04

# %%
# Step 5: Making Predictions
# Predictions on test data
predictions = model.predict(X_test)
# Inverse transform to get actual values
predictions = scaler.inverse_transform(predictions.reshape(-1, 1))

# %%
# Step 6: Evaluation
# Inverse transform to get actual values of y_test
y_test_actual = scaler.inverse_transform(y_test.reshape(-1, 1))

# %%
# Plot the data
plt.figure(figsize=(14, 5))
plt.plot(y_test_actual, color='blue', label='Actual NFLX Stock Price')
plt.plot(predictions, color='red', label='Predicted NFLX Stock Price')
plt.title('NFLX Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('NFLX Stock Price')
plt.legend()
plt.show()

# %%
# Save the model
model.save('stock_price_prediction_model.h5')
